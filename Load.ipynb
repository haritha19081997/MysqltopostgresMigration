# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("POC-MySQL-Loader-Stable")
    .config("spark.jars", "/home/jovyan/jars/mysql-connector-j.jar,/home/jovyan/jars/postgresql.jar")
    .config("spark.sql.shuffle.partitions", "8")
    .config("spark.driver.memory", "4g")     # if Docker memory is high, change to 6g
    .config("spark.executor.memory", "2g")   # local mode uses driver mostly; harmless
    .getOrCreate()
)

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://9ed76452174a:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>POC-MySQL-Loader-Stable</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from pyspark.sql import functions as F

MYSQL_URL = "jdbc:mysql://mysql:3306/pocdb"
MYSQL_USER = "pocuser"
MYSQL_PASSWORD = "pocpass"

PLAZA_IDS = ["000001", "000002", "000003", "000004"]
plaza_arr = F.array(*[F.lit(x) for x in PLAZA_IDS])
plaza_count = len(PLAZA_IDS)

start_id, end_id = 1001, 51_000   # start after your existing 1000 rows

df = spark.range(start_id, end_id + 1).withColumnRenamed("id", "Transaction_ID")

df = (df
  .withColumn("TIPID", (F.col("Transaction_ID") % 10_000_000).cast("bigint"))
  .withColumn("UFMID", (F.col("Transaction_ID") % 5_000_000).cast("bigint"))
  .withColumn("Plaza_ID", F.element_at(plaza_arr, (F.pmod(F.col("Transaction_ID"), plaza_count) + 1).cast("int")))
  .withColumn("Lane_ID", (F.col("Transaction_ID") % 20).cast("int"))
  .withColumn("Full_Fare", F.lit(2.50).cast("decimal(6,2)"))
  .withColumn("ETC_Fare", F.lit(2.00).cast("decimal(6,2)"))
  .withColumn("Indicated_Fare", F.lit(2.25).cast("decimal(6,2)"))
  .withColumn(
      "Transaction_DateTime",
      F.to_timestamp(F.from_unixtime(
          F.unix_timestamp(F.current_timestamp()) - (F.col("Transaction_ID") % 86400).cast("int")
      ))
  )
  .withColumn("Revenue_Type", F.lit("ETC"))
  .withColumn("Exception_Codes", F.lit(None).cast("string"))
  .withColumn("Zero_Fare_Override_Flag", F.lit(0))
  .withColumn("AVC_Class", F.lit(1))
  .withColumn("Vehicle_Speed", F.lit(60))
  .withColumn("Vehicle_Length", F.lit(15))
  .withColumn("Lane_Position", F.lit("N"))
  .withColumn("Exempt_Flag", F.lit(0))
  .withColumn("Transaction_Type", F.lit("COMPLETED_COLLECTABLE"))
  .withColumn("Uncollectable_Reason", F.lit(None).cast("string"))
  .withColumn("Account_ID", (F.col("Transaction_ID") % 2_000_000).cast("int"))
  .withColumn("UFM_Send_DateTime", F.current_timestamp())
  .withColumn("UFM_Pay_Method", F.lit("ETC"))
  .withColumn("UFM_Discount_Fare", F.lit(1.75).cast("decimal(6,2)"))
  .withColumn("UFM_Full_Fare", F.lit(2.50).cast("decimal(6,2)"))
  .withColumn("UFM_Indicated_Fare", F.lit(2.25).cast("decimal(6,2)"))
  .withColumn("Region_Code", F.lit(1))
  .withColumn("Tag_Agency_ID", F.lit(10))
  .withColumn("Tag_ID", (F.col("Transaction_ID") % 9_000_000).cast("int"))
  .withColumn("Tag_Class", F.lit(2))
  .withColumn("Tag_Status", F.lit("ACTIVE"))
  .withColumn("Plate_Jurisdiction", F.lit("FL"))
  .withColumn("Plate_Number", F.concat(F.lit("P"), F.lpad((F.col("Transaction_ID") % 1_000_000).cast("string"), 6, "0")))
  .withColumn("Plate_Type", F.lit("REG"))
  .withColumn("Plate_Type_Prefix", F.lit(None).cast("string"))
  .withColumn("Plate_Type_Suffix", F.lit(None).cast("string"))
  .withColumn("Plate_Country", F.lit("US"))
  .withColumn("Horizontal_Plate_Position", F.lit(1))
  .withColumn("Vertical_Plate_Position", F.lit(1))
  .withColumn("Horizontal_Plate_Size", F.lit(100))
  .withColumn("Vertical_Plate_Size", F.lit(50))
  .withColumn("Plate_Number_Confidence", F.lit(95))
  .withColumn("Jurisdiction_Confidence", F.lit(98))
  .withColumn("Image_Name", F.lit(None).cast("string"))
  .withColumn("Image_Location", F.lit(None).cast("string"))
  .withColumn("Number_of_Front_Images", F.lit(0))
  .withColumn("Number_of_Rear_Images", F.lit(0))
  .withColumn("Image_Disposition", F.lit(0))
  .withColumn("Image_Reason_Code", F.lit(0))
  .withColumn("InsertedOn", F.current_timestamp())
  .withColumn("InsertedBy", F.lit("POC"))
  .withColumn("UpdatedOn", F.current_timestamp())
  .withColumn("UpdatedBy", F.lit("POC"))
  .withColumn("CycleName", F.lit("POC"))
  .withColumn("BatchId", F.lit(1).cast("decimal(38,0)"))
  .withColumn("Soft_Delete", F.lit(0))
).repartition(4)  # KEY: keep this small on laptop

(df.write.format("jdbc")
 .option("url", MYSQL_URL)
 .option("dbtable", "`Transaction`")
 .option("user", MYSQL_USER)
 .option("password", MYSQL_PASSWORD)
 .option("driver", "com.mysql.cj.jdbc.Driver")
 .option("batchsize", "500")                 # KEY: small batch prevents heap blowup
 .option("rewriteBatchedStatements", "false")# KEY: prevents huge multi-values SQL
 .mode("append")
 .save())

# %%
# !pip -q install jaydebeapi JPype1

# %%
import jaydebeapi

MYSQL_USER = "pocuser"
MYSQL_PASSWORD = "pocpass"

MYSQL_JDBC_URL = "jdbc:mysql://mysql:3306/pocdb"
MYSQL_JAR = "/home/jovyan/jars/mysql-connector-j.jar"


def get_last_id():
    conn = jaydebeapi.connect(
        "com.mysql.cj.jdbc.Driver",
        MYSQL_JDBC_URL,
        [MYSQL_USER, MYSQL_PASSWORD],
        MYSQL_JAR
    )

    conn.jconn.setAutoCommit(False)   # disable autocommit

    cur = conn.cursor()
    cur.execute("SELECT last_id FROM load_checkpoint WHERE job_name='txn_load';")

    row = cur.fetchone()

    cur.close()
    conn.close()

    return int(row[0])


def update_last_id(new_last_id: int):
    conn = jaydebeapi.connect(
        "com.mysql.cj.jdbc.Driver",
        MYSQL_JDBC_URL,
        [MYSQL_USER, MYSQL_PASSWORD],
        MYSQL_JAR
    )

    conn.jconn.setAutoCommit(False)   # disable autocommit

    cur = conn.cursor()

    cur.execute(
        "UPDATE load_checkpoint SET last_id=? WHERE job_name='txn_load';",
        (new_last_id,)
    )

    conn.commit()   # now works

    cur.close()
    conn.close()

# %%
print("Before:", get_last_id())
update_last_id(51000)
print("After :", get_last_id())
# Out:
# Before: 51000
# After : 51000

# %%
from pyspark.sql import SparkSession, functions as F
import jaydebeapi

# -----------------------------
# SPARK SESSION (stable)
# -----------------------------
spark = (
    SparkSession.builder
    .appName("POC-Transaction-93M-Loader")
    .config("spark.jars", "/home/jovyan/jars/mysql-connector-j.jar,/home/jovyan/jars/postgresql.jar")
    .config("spark.sql.shuffle.partitions", "8")
    .config("spark.driver.memory", "4g")   # if Docker memory is high, set 6g
    .getOrCreate()
)

# -----------------------------
# MYSQL CONFIG
# -----------------------------
MYSQL_USER = "pocuser"
MYSQL_PASSWORD = "pocpass"
MYSQL_JDBC_URL = "jdbc:mysql://mysql:3306/pocdb"
MYSQL_JAR = "/home/jovyan/jars/mysql-connector-j.jar"

MYSQL_SPARK_URL = "jdbc:mysql://mysql:3306/pocdb"

TABLE_NAME = "`Transaction`"
CHECKPOINT_JOB = "txn_load"

TOTAL_ROWS = 93_000_000
BATCH_ROWS = 500_000        # safe. If stable, increase to 1_000_000
WRITE_PARTITIONS = 4        # keep small to avoid JDBC heap OOM
JDBC_BATCHSIZE = "500"      # key: prevents heap OOM in mysql driver

# -----------------------------
# PLAZA IDS (replace with your actual list)
# -----------------------------
PLAZA_IDS = ["000001", "000002", "000003", "000004"]
plaza_arr = F.array(*[F.lit(x) for x in PLAZA_IDS])
plaza_count = len(PLAZA_IDS)

# -----------------------------
# CHECKPOINT helpers (UPSERT)
# -----------------------------
def get_last_id():
    conn = jaydebeapi.connect(
        "com.mysql.cj.jdbc.Driver",
        MYSQL_JDBC_URL,
        [MYSQL_USER, MYSQL_PASSWORD],
        MYSQL_JAR
    )
    cur = conn.cursor()
    cur.execute("SELECT last_id FROM load_checkpoint WHERE job_name=?;", (CHECKPOINT_JOB,))
    row = cur.fetchone()
    cur.close()
    conn.close()
    return int(row[0]) if row else 0

def upsert_last_id(new_last_id: int):
    conn = jaydebeapi.connect(
        "com.mysql.cj.jdbc.Driver",
        MYSQL_JDBC_URL,
        [MYSQL_USER, MYSQL_PASSWORD],
        MYSQL_JAR
    )
    cur = conn.cursor()
    cur.execute("""
        INSERT INTO load_checkpoint (job_name, last_id)
        VALUES (?, ?)
        ON DUPLICATE KEY UPDATE last_id = VALUES(last_id);
    """, (CHECKPOINT_JOB, int(new_last_id)))
    cur.close()
    conn.close()

# -----------------------------
# BATCH DF generator (deterministic)
# -----------------------------
def make_batch(start_id: int, end_id: int):
    base = spark.range(start_id, end_id + 1).withColumnRenamed("id", "Transaction_ID")

    df = (base
      .withColumn("TIPID", (F.col("Transaction_ID") % 10_000_000).cast("bigint"))
      .withColumn("UFMID", (F.col("Transaction_ID") % 5_000_000).cast("bigint"))

      # rotate plaza ids
      .withColumn("Plaza_ID", F.element_at(plaza_arr, (F.pmod(F.col("Transaction_ID"), plaza_count) + 1).cast("int")))

      .withColumn("Lane_ID", (F.col("Transaction_ID") % 20).cast("int"))

      .withColumn("Full_Fare", F.lit(2.50).cast("decimal(6,2)"))
      .withColumn("ETC_Fare", F.lit(2.00).cast("decimal(6,2)"))
      .withColumn("Indicated_Fare", F.lit(2.25).cast("decimal(6,2)"))

      # portable timestamp arithmetic (no INTERVAL)
      .withColumn(
          "Transaction_DateTime",
          F.to_timestamp(F.from_unixtime(
              F.unix_timestamp(F.current_timestamp()) - (F.col("Transaction_ID") % 86400).cast("int")
          ))
      )

      .withColumn("Revenue_Type", F.lit("ETC"))
      .withColumn("Exception_Codes", F.lit(None).cast("string"))

      .withColumn("Zero_Fare_Override_Flag", F.lit(0))
      .withColumn("AVC_Class", F.lit(1))

      .withColumn("Vehicle_Speed", (F.col("Transaction_ID") % 90).cast("int"))
      .withColumn("Vehicle_Length", (F.col("Transaction_ID") % 30).cast("int"))

      .withColumn("Lane_Position", F.lit("N"))
      .withColumn("Exempt_Flag", F.lit(0))

      .withColumn(
          "Transaction_Type",
          F.when((F.col("Transaction_ID") % 3) == 0, "COMPLETED_COLLECTABLE")
           .when((F.col("Transaction_ID") % 3) == 1, "COMPLETED_UNCOLLECTABLE")
           .otherwise("INCOMPLETE")
      )
      .withColumn("Uncollectable_Reason", F.lit(None).cast("string"))

      .withColumn("Account_ID", (F.col("Transaction_ID") % 2_000_000).cast("int"))
      .withColumn("UFM_Send_DateTime", F.current_timestamp())
      .withColumn("UFM_Pay_Method", F.when((F.col("Transaction_ID") % 2) == 0, "ETC").otherwise("VIOLATOR"))

      .withColumn("UFM_Discount_Fare", F.lit(1.75).cast("decimal(6,2)"))
      .withColumn("UFM_Full_Fare", F.lit(2.50).cast("decimal(6,2)"))
      .withColumn("UFM_Indicated_Fare", F.lit(2.25).cast("decimal(6,2)"))

      .withColumn("Region_Code", F.lit(1))
      .withColumn("Tag_Agency_ID", F.lit(10))
      .withColumn("Tag_ID", (F.col("Transaction_ID") % 9_000_000).cast("int"))
      .withColumn("Tag_Class", (F.col("Transaction_ID") % 10).cast("int"))
      .withColumn("Tag_Status", F.lit("ACTIVE"))

      .withColumn("Plate_Jurisdiction", F.lit("FL"))
      .withColumn("Plate_Number", F.concat(F.lit("P"), F.lpad((F.col("Transaction_ID") % 1_000_000).cast("string"), 6, "0")))
      .withColumn("Plate_Type", F.lit("REG"))
      .withColumn("Plate_Type_Prefix", F.lit(None).cast("string"))
      .withColumn("Plate_Type_Suffix", F.lit(None).cast("string"))
      .withColumn("Plate_Country", F.lit("US"))

      .withColumn("Horizontal_Plate_Position", F.lit(1))
      .withColumn("Vertical_Plate_Position", F.lit(1))
      .withColumn("Horizontal_Plate_Size", F.lit(100))
      .withColumn("Vertical_Plate_Size", F.lit(50))

      .withColumn("Plate_Number_Confidence", F.lit(95))
      .withColumn("Jurisdiction_Confidence", F.lit(98))

      .withColumn("Image_Name", F.lit(None).cast("string"))
      .withColumn("Image_Location", F.lit(None).cast("string"))
      .withColumn("Number_of_Front_Images", F.lit(0))
      .withColumn("Number_of_Rear_Images", F.lit(0))
      .withColumn("Image_Disposition", F.lit(0))
      .withColumn("Image_Reason_Code", F.lit(0))

      .withColumn("InsertedOn", F.current_timestamp())
      .withColumn("InsertedBy", F.lit("POC"))
      .withColumn("UpdatedOn", F.current_timestamp())
      .withColumn("UpdatedBy", F.lit("POC"))
      .withColumn("CycleName", F.lit("POC"))
      .withColumn("BatchId", F.lit(1).cast("decimal(38,0)"))
      .withColumn("Soft_Delete", F.lit(0))
    ).repartition(WRITE_PARTITIONS)

    return df

# -----------------------------
# RUN LOOP (resume-safe)
# -----------------------------
last_id = get_last_id()
start = last_id + 1

print(f"Checkpoint last_id={last_id:,}. Next start={start:,}. Target={TOTAL_ROWS:,}")

while start <= TOTAL_ROWS:
    end = min(start + BATCH_ROWS - 1, TOTAL_ROWS)
    print(f"Loading {start:,} → {end:,}")

    batch_df = make_batch(start, end)

    (batch_df.write.format("jdbc")
     .option("url", MYSQL_SPARK_URL)
     .option("dbtable", TABLE_NAME)
     .option("user", MYSQL_USER)
     .option("password", MYSQL_PASSWORD)
     .option("driver", "com.mysql.cj.jdbc.Driver")
     .option("batchsize", JDBC_BATCHSIZE)
     .option("rewriteBatchedStatements", "false")
     .mode("append")
     .save())

    upsert_last_id(end)
    print(f"✅ Updated checkpoint to {end:,}")

    start = end + 1

print("✅ Finished loading to 93,000,000 rows.")
# Out:
# Checkpoint last_id=551,000. Next start=551,001. Target=93,000,000
# Loading 551,001 → 1,051,000
# ✅ Updated checkpoint to 1,051,000
# Loading 1,051,001 → 1,551,000
# ✅ Updated checkpoint to 1,551,000
# Loading 1,551,001 → 2,051,000
# ✅ Updated checkpoint to 2,051,000
# Loading 2,051,001 → 2,551,000
# ✅ Updated checkpoint to 2,551,000
# Loading 2,551,001 → 3,051,000
# ✅ Updated checkpoint to 3,051,000
# Loading 3,051,001 → 3,551,000
# ✅ Updated checkpoint to 3,551,000
# Loading 3,551,001 → 4,051,000
# ✅ Updated checkpoint to 4,051,000
# Loading 4,051,001 → 4,551,000
# ✅ Updated checkpoint to 4,551,000
# Loading 4,551,001 → 5,051,000
# ✅ Updated checkpoint to 5,051,000
# Loading 5,051,001 → 5,551,000
# ✅ Updated checkpoint to 5,551,000
# Loading 5,551,001 → 6,051,000
# ✅ Updated checkpoint to 6,051,000
# Loading 6,051,001 → 6,551,000
# ✅ Updated checkpoint to 6,551,000
# Loading 6,551,001 → 7,051,000
# ✅ Updated checkpoint to 7,051,000
# Loading 7,051,001 → 7,551,000
# ✅ Updated checkpoint to 7,551,000
# Loading 7,551,001 → 8,051,000
# ✅ Updated checkpoint to 8,051,000
# Loading 8,051,001 → 8,551,000
# ✅ Updated checkpoint to 8,551,000
# Loading 8,551,001 → 9,051,000
# ✅ Updated checkpoint to 9,051,000
# Loading 9,051,001 → 9,551,000
# ✅ Updated checkpoint to 9,551,000
# Loading 9,551,001 → 10,051,000
# ✅ Updated checkpoint to 10,051,000
# Loading 10,051,001 → 10,551,000
# ✅ Updated checkpoint to 10,551,000
# Loading 10,551,001 → 11,051,000
# ✅ Updated checkpoint to 11,051,000
# Loading 11,051,001 → 11,551,000
# ✅ Updated checkpoint to 11,551,000
# Loading 11,551,001 → 12,051,000
# ✅ Updated checkpoint to 12,051,000
# Loading 12,051,001 → 12,551,000
# ✅ Updated checkpoint to 12,551,000
# Loading 12,551,001 → 13,051,000
# ✅ Updated checkpoint to 13,051,000
# Loading 13,051,001 → 13,551,000
# ✅ Updated checkpoint to 13,551,000
# Loading 13,551,001 → 14,051,000
# ✅ Updated checkpoint to 14,051,000
# Loading 14,051,001 → 14,551,000
# ✅ Updated checkpoint to 14,551,000
# Loading 14,551,001 → 15,051,000
# ✅ Updated checkpoint to 15,051,000
# Loading 15,051,001 → 15,551,000
# ✅ Updated checkpoint to 15,551,000
# Loading 15,551,001 → 16,051,000
# ✅ Updated checkpoint to 16,051,000
# Loading 16,051,001 → 16,551,000
# ✅ Updated checkpoint to 16,551,000
# Loading 16,551,001 → 17,051,000
# ✅ Updated checkpoint to 17,051,000
# Loading 17,051,001 → 17,551,000
# ✅ Updated checkpoint to 17,551,000
# Loading 17,551,001 → 18,051,000
# ✅ Updated checkpoint to 18,051,000
# Loading 18,051,001 → 18,551,000
# ✅ Updated checkpoint to 18,551,000
# Loading 18,551,001 → 19,051,000
# ✅ Updated checkpoint to 19,051,000
# Loading 19,051,001 → 19,551,000
# ✅ Updated checkpoint to 19,551,000
# Loading 19,551,001 → 20,051,000
# ✅ Updated checkpoint to 20,051,000
# Loading 20,051,001 → 20,551,000
# ✅ Updated checkpoint to 20,551,000
# Loading 20,551,001 → 21,051,000
# ✅ Updated checkpoint to 21,051,000
# Loading 21,051,001 → 21,551,000
# ✅ Updated checkpoint to 21,551,000
# Loading 21,551,001 → 22,051,000
# ✅ Updated checkpoint to 22,051,000
# Loading 22,051,001 → 22,551,000
# ✅ Updated checkpoint to 22,551,000
# Loading 22,551,001 → 23,051,000
# ✅ Updated checkpoint to 23,051,000
# Loading 23,051,001 → 23,551,000
# ✅ Updated checkpoint to 23,551,000
# Loading 23,551,001 → 24,051,000
# ✅ Updated checkpoint to 24,051,000
# Loading 24,051,001 → 24,551,000
# ✅ Updated checkpoint to 24,551,000
# Loading 24,551,001 → 25,051,000
# ✅ Updated checkpoint to 25,051,000
# Loading 25,051,001 → 25,551,000
# ✅ Updated checkpoint to 25,551,000
# Loading 25,551,001 → 26,051,000
# ✅ Updated checkpoint to 26,051,000
# Loading 26,051,001 → 26,551,000
# ✅ Updated checkpoint to 26,551,000
# Loading 26,551,001 → 27,051,000
# ✅ Updated checkpoint to 27,051,000
# Loading 27,051,001 → 27,551,000
# ✅ Updated checkpoint to 27,551,000
# Loading 27,551,001 → 28,051,000
# ✅ Updated checkpoint to 28,051,000
# Loading 28,051,001 → 28,551,000
# ✅ Updated checkpoint to 28,551,000
# Loading 28,551,001 → 29,051,000
# ✅ Updated checkpoint to 29,051,000
# Loading 29,051,001 → 29,551,000
# ✅ Updated checkpoint to 29,551,000
# Loading 29,551,001 → 30,051,000
# ✅ Updated checkpoint to 30,051,000
# Loading 30,051,001 → 30,551,000
# ✅ Updated checkpoint to 30,551,000
# Loading 30,551,001 → 31,051,000
# ✅ Updated checkpoint to 31,051,000
# Loading 31,051,001 → 31,551,000
# ✅ Updated checkpoint to 31,551,000
# Loading 31,551,001 → 32,051,000
# ✅ Updated checkpoint to 32,051,000
# Loading 32,051,001 → 32,551,000
# ✅ Updated checkpoint to 32,551,000
# Loading 32,551,001 → 33,051,000
# ✅ Updated checkpoint to 33,051,000
# Loading 33,051,001 → 33,551,000
# ✅ Updated checkpoint to 33,551,000
# Loading 33,551,001 → 34,051,000
# ✅ Updated checkpoint to 34,051,000
# Loading 34,051,001 → 34,551,000
# ✅ Updated checkpoint to 34,551,000
# Loading 34,551,001 → 35,051,000
# ✅ Updated checkpoint to 35,051,000
# Loading 35,051,001 → 35,551,000
# ✅ Updated checkpoint to 35,551,000
# Loading 35,551,001 → 36,051,000
# ✅ Updated checkpoint to 36,051,000
# Loading 36,051,001 → 36,551,000
# ✅ Updated checkpoint to 36,551,000
# Loading 36,551,001 → 37,051,000
# ✅ Updated checkpoint to 37,051,000
# Loading 37,051,001 → 37,551,000
# ✅ Updated checkpoint to 37,551,000
# Loading 37,551,001 → 38,051,000
# ✅ Updated checkpoint to 38,051,000
# Loading 38,051,001 → 38,551,000
# ✅ Updated checkpoint to 38,551,000
# Loading 38,551,001 → 39,051,000
# ✅ Updated checkpoint to 39,051,000
# Loading 39,051,001 → 39,551,000
# ✅ Updated checkpoint to 39,551,000
# Loading 39,551,001 → 40,051,000
# ✅ Updated checkpoint to 40,051,000
# Loading 40,051,001 → 40,551,000
# ✅ Updated checkpoint to 40,551,000
# Loading 40,551,001 → 41,051,000
# ✅ Updated checkpoint to 41,051,000
# Loading 41,051,001 → 41,551,000
# ✅ Updated checkpoint to 41,551,000
# Loading 41,551,001 → 42,051,000
# ✅ Updated checkpoint to 42,051,000
# Loading 42,051,001 → 42,551,000
# ✅ Updated checkpoint to 42,551,000
# Loading 42,551,001 → 43,051,000
# ✅ Updated checkpoint to 43,051,000
# Loading 43,051,001 → 43,551,000
# ✅ Updated checkpoint to 43,551,000
# Loading 43,551,001 → 44,051,000
# ✅ Updated checkpoint to 44,051,000
# Loading 44,051,001 → 44,551,000
# ✅ Updated checkpoint to 44,551,000
# Loading 44,551,001 → 45,051,000
# ✅ Updated checkpoint to 45,051,000
# Loading 45,051,001 → 45,551,000
# ✅ Updated checkpoint to 45,551,000
# Loading 45,551,001 → 46,051,000
# ✅ Updated checkpoint to 46,051,000
# Loading 46,051,001 → 46,551,000
# ✅ Updated checkpoint to 46,551,000
# Loading 46,551,001 → 47,051,000
# ✅ Updated checkpoint to 47,051,000
# Loading 47,051,001 → 47,551,000
# ✅ Updated checkpoint to 47,551,000
# Loading 47,551,001 → 48,051,000
# ✅ Updated checkpoint to 48,051,000
# Loading 48,051,001 → 48,551,000
# ✅ Updated checkpoint to 48,551,000
# Loading 48,551,001 → 49,051,000
# ✅ Updated checkpoint to 49,051,000
# Loading 49,051,001 → 49,551,000
# ✅ Updated checkpoint to 49,551,000
# Loading 49,551,001 → 50,051,000
# ✅ Updated checkpoint to 50,051,000
# Loading 50,051,001 → 50,551,000
# ✅ Updated checkpoint to 50,551,000
# Loading 50,551,001 → 51,051,000
# ✅ Updated checkpoint to 51,051,000
# Loading 51,051,001 → 51,551,000
# ✅ Updated checkpoint to 51,551,000
# Loading 51,551,001 → 52,051,000
# ✅ Updated checkpoint to 52,051,000
# Loading 52,051,001 → 52,551,000
# ✅ Updated checkpoint to 52,551,000
# Loading 52,551,001 → 53,051,000
# ✅ Updated checkpoint to 53,051,000
# Loading 53,051,001 → 53,551,000
# ✅ Updated checkpoint to 53,551,000
# Loading 53,551,001 → 54,051,000
# ✅ Updated checkpoint to 54,051,000
# Loading 54,051,001 → 54,551,000
# ✅ Updated checkpoint to 54,551,000
# Loading 54,551,001 → 55,051,000
# ✅ Updated checkpoint to 55,051,000
# Loading 55,051,001 → 55,551,000
# ✅ Updated checkpoint to 55,551,000
# Loading 55,551,001 → 56,051,000
# ✅ Updated checkpoint to 56,051,000
# Loading 56,051,001 → 56,551,000
# ✅ Updated checkpoint to 56,551,000
# Loading 56,551,001 → 57,051,000
# ✅ Updated checkpoint to 57,051,000
# Loading 57,051,001 → 57,551,000
# ✅ Updated checkpoint to 57,551,000
# Loading 57,551,001 → 58,051,000
# ✅ Updated checkpoint to 58,051,000
# Loading 58,051,001 → 58,551,000
# ✅ Updated checkpoint to 58,551,000
# Loading 58,551,001 → 59,051,000
# ✅ Updated checkpoint to 59,051,000
# Loading 59,051,001 → 59,551,000
# ✅ Updated checkpoint to 59,551,000
# Loading 59,551,001 → 60,051,000
# ✅ Updated checkpoint to 60,051,000
# Loading 60,051,001 → 60,551,000
# ✅ Updated checkpoint to 60,551,000
# Loading 60,551,001 → 61,051,000
# ✅ Updated checkpoint to 61,051,000
# Loading 61,051,001 → 61,551,000
# ✅ Updated checkpoint to 61,551,000
# Loading 61,551,001 → 62,051,000
# ✅ Updated checkpoint to 62,051,000
# Loading 62,051,001 → 62,551,000
# ✅ Updated checkpoint to 62,551,000
# Loading 62,551,001 → 63,051,000
# ✅ Updated checkpoint to 63,051,000
# Loading 63,051,001 → 63,551,000
# ✅ Updated checkpoint to 63,551,000
# Loading 63,551,001 → 64,051,000
# ✅ Updated checkpoint to 64,051,000
# Loading 64,051,001 → 64,551,000
# ✅ Updated checkpoint to 64,551,000
# Loading 64,551,001 → 65,051,000
# ✅ Updated checkpoint to 65,051,000
# Loading 65,051,001 → 65,551,000
# ✅ Updated checkpoint to 65,551,000
# Loading 65,551,001 → 66,051,000
# ✅ Updated checkpoint to 66,051,000
# Loading 66,051,001 → 66,551,000
# ✅ Updated checkpoint to 66,551,000
# Loading 66,551,001 → 67,051,000
# ✅ Updated checkpoint to 67,051,000
# Loading 67,051,001 → 67,551,000
# ✅ Updated checkpoint to 67,551,000
# Loading 67,551,001 → 68,051,000
# ✅ Updated checkpoint to 68,051,000
# Loading 68,051,001 → 68,551,000
# ✅ Updated checkpoint to 68,551,000
# Loading 68,551,001 → 69,051,000
# ✅ Updated checkpoint to 69,051,000
# Loading 69,051,001 → 69,551,000
# ✅ Updated checkpoint to 69,551,000
# Loading 69,551,001 → 70,051,000
# ✅ Updated checkpoint to 70,051,000
# Loading 70,051,001 → 70,551,000
# ✅ Updated checkpoint to 70,551,000
# Loading 70,551,001 → 71,051,000
# ✅ Updated checkpoint to 71,051,000
# Loading 71,051,001 → 71,551,000
# ✅ Updated checkpoint to 71,551,000
# Loading 71,551,001 → 72,051,000
# ✅ Updated checkpoint to 72,051,000
# Loading 72,051,001 → 72,551,000
# ✅ Updated checkpoint to 72,551,000
# Loading 72,551,001 → 73,051,000
# ✅ Updated checkpoint to 73,051,000
# Loading 73,051,001 → 73,551,000
# ✅ Updated checkpoint to 73,551,000
# Loading 73,551,001 → 74,051,000
# ✅ Updated checkpoint to 74,051,000
# Loading 74,051,001 → 74,551,000
# ✅ Updated checkpoint to 74,551,000
# Loading 74,551,001 → 75,051,000
# ✅ Updated checkpoint to 75,051,000
# Loading 75,051,001 → 75,551,000
# ✅ Updated checkpoint to 75,551,000
# Loading 75,551,001 → 76,051,000
# ✅ Updated checkpoint to 76,051,000
# Loading 76,051,001 → 76,551,000
# ✅ Updated checkpoint to 76,551,000
# Loading 76,551,001 → 77,051,000
# ✅ Updated checkpoint to 77,051,000
# Loading 77,051,001 → 77,551,000
# ✅ Updated checkpoint to 77,551,000
# Loading 77,551,001 → 78,051,000
# ✅ Updated checkpoint to 78,051,000
# Loading 78,051,001 → 78,551,000
# ✅ Updated checkpoint to 78,551,000
# Loading 78,551,001 → 79,051,000
# ✅ Updated checkpoint to 79,051,000
# Loading 79,051,001 → 79,551,000
# ✅ Updated checkpoint to 79,551,000
# Loading 79,551,001 → 80,051,000
# ✅ Updated checkpoint to 80,051,000
# Loading 80,051,001 → 80,551,000
# ✅ Updated checkpoint to 80,551,000
# Loading 80,551,001 → 81,051,000
# ✅ Updated checkpoint to 81,051,000
# Loading 81,051,001 → 81,551,000
# ✅ Updated checkpoint to 81,551,000
# Loading 81,551,001 → 82,051,000
# ✅ Updated checkpoint to 82,051,000
# Loading 82,051,001 → 82,551,000
# ✅ Updated checkpoint to 82,551,000
# Loading 82,551,001 → 83,051,000
# ✅ Updated checkpoint to 83,051,000
# Loading 83,051,001 → 83,551,000
# ✅ Updated checkpoint to 83,551,000
# Loading 83,551,001 → 84,051,000
# ✅ Updated checkpoint to 84,051,000
# Loading 84,051,001 → 84,551,000
# ✅ Updated checkpoint to 84,551,000
# Loading 84,551,001 → 85,051,000
# ✅ Updated checkpoint to 85,051,000
# Loading 85,051,001 → 85,551,000
# ✅ Updated checkpoint to 85,551,000
# Loading 85,551,001 → 86,051,000
# ✅ Updated checkpoint to 86,051,000
# Loading 86,051,001 → 86,551,000
# ✅ Updated checkpoint to 86,551,000
# Loading 86,551,001 → 87,051,000
# ✅ Updated checkpoint to 87,051,000
# Loading 87,051,001 → 87,551,000
# ✅ Updated checkpoint to 87,551,000
# Loading 87,551,001 → 88,051,000
# ✅ Updated checkpoint to 88,051,000
# Loading 88,051,001 → 88,551,000
# ✅ Updated checkpoint to 88,551,000
# Loading 88,551,001 → 89,051,000
# ✅ Updated checkpoint to 89,051,000
# Loading 89,051,001 → 89,551,000
# ✅ Updated checkpoint to 89,551,000
# Loading 89,551,001 → 90,051,000
# ✅ Updated checkpoint to 90,051,000
# Loading 90,051,001 → 90,551,000
# ✅ Updated checkpoint to 90,551,000
# Loading 90,551,001 → 91,051,000
# ✅ Updated checkpoint to 91,051,000
# Loading 91,051,001 → 91,551,000
# ✅ Updated checkpoint to 91,551,000
# Loading 91,551,001 → 92,051,000
# ✅ Updated checkpoint to 92,051,000
# Loading 92,051,001 → 92,551,000
# ✅ Updated checkpoint to 92,551,000
# Loading 92,551,001 → 93,000,000
# ✅ Updated checkpoint to 93,000,000
# ✅ Finished loading to 93,000,000 rows.
